# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV


from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImPipeline

# %%
df = pd.read_pickle("../data/reviews_vector_ngrams.pkl")

# %%
minority_count = df[df['binary'] == 0].shape[0]
# random sample of majority class
majority_sample = df[df['binary'] == 1].sample(n=minority_count, random_state=42)

# merge to make balanced dataset
balanced_df = pd.concat([df[df['binary'] == 0], majority_sample])

balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
y_prime = balanced_df["binary"]
X=df[df.columns[4:]]
y=df["binary"]
X_prime = balanced_df[balanced_df.columns[4:]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

# %%
X_train_prime, X_test_prime, y_train_prime, y_test_prime = train_test_split(X_prime, y_prime, test_size=0.2, stratify=y_prime, random_state=42)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_transformed = scaler.transform(X_train)
X_test_transformed = scaler.transform(X_test)

# %%
scaler_prime = StandardScaler()
scaler_prime.fit(X_train_prime)
X_train_transformed_prime = scaler.transform(X_train_prime)
X_test_transformed_prime = scaler.transform(X_test_prime)

# %%
# instantiate SMOTE sampler, fit it to the training data, then resample the data
# X_train_sm, y_train_sm = SMOTE(random_state=1).fit_resample(X_train_transformed, y_train)

# %%
# # check what SMOTE has done

# print('Original class distribution')
# display(pd.Series(y_train).value_counts().sort_index())

# print('\nResampled class distribution')
# display(pd.Series(y_train_sm).value_counts().sort_index())

# %% [markdown]
# from the [imblearn.pipeline.Pipeline](https://imbalanced-learn.org/stable/references/generated/imblearn.pipeline.Pipeline.html)

# %%
estimators = [('normalise', StandardScaler()),
              ('model', DecisionTreeClassifier(max_depth=15, random_state=12))]
# smote
# estimators = [('normalise', StandardScaler()),
#               ('smote', SMOTE(random_state=1)),
#               ('model', DecisionTreeClassifier(max_depth=15, random_state=12))]

# pipe = ImPipeline(estimators, verbose=True)

pipe = Pipeline(estimators, verbose = True)
pipe.fit(X_train, y_train)
# Out:
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=   2.7s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  23.8s
# Pipeline(steps=[('normalise', StandardScaler()),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=15, random_state=12))],
#          verbose=True)

# %%
pipe_prime = Pipeline(estimators, verbose = True)

pipe_prime.fit(X_train_transformed_prime, y_train_prime)
# Out:
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=   0.8s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   9.4s
# Pipeline(steps=[('normalise', StandardScaler()),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=15, random_state=12))],
#          verbose=True)

# %%
y_test_pred = pipe.predict(X_test_transformed)

# %%
y_test_pred_prime = pipe_prime.predict(X_test_transformed_prime)

# %%
pipe.score(X_test_transformed, y_test)
# Out:
# 0.7015874085429196

# %%
pipe_prime.score(X_test_transformed_prime, y_test_prime)
# Out:
# 0.7512626092577878

# %% [markdown]
# Sparsity: SMOTE might change the inherent sparsity of TF-IDF features by creating synthetic samples with more non-zero values than real text data.
#
# High-Dimensionality: The effectiveness of SMOTE decreases in high-dimensional TF-IDF spaces due to the diminishing significance of nearest neighbors.
#
# Interpretability: Synthetic TF-IDF vectors produced by SMOTE may not correspond to any genuine or meaningful text, challenging the interpretability of the data.
#
# Relevance of Features: SMOTE can inadvertently amplify the influence of less relevant or noisy features in the synthetic samples it generates for TF-IDF data.

# %%
# confusion matrix
conmat = pd.DataFrame(
    data = confusion_matrix(y_test, y_test_pred),
    index = ['true 0', 'true 1'],
    columns = ['predicted 0', 'predicted 1']
)
display(conmat)
# Out:
#         predicted 0  predicted 1
# true 0        31714         5411
# true 1        47733        93231

# %%
# confusion matrix
conmat = pd.DataFrame(
    data = confusion_matrix(y_test_prime, y_test_pred_prime),
    index = ['true 0', 'true 1'],
    columns = ['predicted 0', 'predicted 1']
)
display(conmat)
# Out:
#         predicted 0  predicted 1
# true 0        31287         5839
# true 1        12630        24495

# %%
# normal
cm = confusion_matrix(y_test, y_test_pred)

# %%
# downsampled
cm_prime = confusion_matrix(y_test_prime, y_test_pred_prime)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix on the test data - DT")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm_prime, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix on the test data - DT - downsampled")
plt.show()

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.85      0.54     37125
#            1       0.95      0.66      0.78    140964
#
#     accuracy                           0.70    178089
#    macro avg       0.67      0.76      0.66    178089
# weighted avg       0.83      0.70      0.73    178089

# %%
print(classification_report(y_test_prime, y_test_pred_prime))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77     37126
#            1       0.81      0.66      0.73     37125
#
#     accuracy                           0.75     74251
#    macro avg       0.76      0.75      0.75     74251
# weighted avg       0.76      0.75      0.75     74251

# %%
# retrieve the decision tree classifier from the pipeline
decision_tree_classifier = pipe[-1]

plt.figure(figsize=(20, 10))
plot_tree(decision_tree_classifier, max_depth=2, filled=True, feature_names=list(X_train.columns), class_names=["0","1"], rounded=True)
plt.show()

# %%
# retrieve the decision tree classifier from the pipeline
decision_tree_classifier_prime = pipe_prime[-1]

plt.figure(figsize=(20, 10))
plot_tree(decision_tree_classifier_prime, max_depth=3, filled=True, feature_names=list(X_train_prime.columns), class_names=["0","1"], rounded=True)
plt.show()

# %%
params = {
    'model__max_depth': [5,10,15],
    'model__min_samples_leaf': [3,5,10],
    'model__random_state':[12],
    'normalise': [StandardScaler()]
}

grid_search = GridSearchCV(pipe, param_grid=params, verbose=1, n_jobs=-2)

# %%
fittedgrid = grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  50.4s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  51.5s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  51.7s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.0s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.1s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.4s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.5s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.5s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.6s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  36.8s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  46.8s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  49.2s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.3s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.5s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.9s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.6s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.8s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  51.0s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.0s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.1s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.1s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.2s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.6s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.9s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.9s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  53.2s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  35.6s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  40.2s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  41.4s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  42.8s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  42.8s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  42.3s
# [Pipeline] ............. (step 2 of 2) Processing model, total= 1.3min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 1.3min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 1.3min
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  46.5s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  47.8s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  47.8s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  47.8s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  48.1s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  48.3s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  46.6s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  49.7s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  50.2s
# [Pipeline] ............. (step 2 of 2) Processing model, total= 4.8min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 4.9min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 5.0min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 5.1min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 5.1min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 5.1min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 4.3min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 4.4min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 4.4min
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  41.9s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  50.1s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.2s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  52.9s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  54.2s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  54.3s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  55.0s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  54.3s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  55.1s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  38.0s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  57.6s
# [Pipeline] ............. (step 2 of 2) Processing model, total= 4.8min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 5.0min
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  57.6s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total= 1.0min
# [Pipeline] ............. (step 2 of 2) Processing model, total=12.3min
# [Pipeline] ............. (step 2 of 2) Processing model, total=12.5min
# [Pipeline] ............. (step 2 of 2) Processing model, total=12.7min
# [Pipeline] ............. (step 2 of 2) Processing model, total=12.7min
# [Pipeline] ............. (step 2 of 2) Processing model, total=12.8min
# [Pipeline] ............. (step 2 of 2) Processing model, total=12.8min
# [Pipeline] ............. (step 2 of 2) Processing model, total=11.2min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 7.0min
# [Pipeline] ............. (step 2 of 2) Processing model, total= 6.7min
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  45.1s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  41.5s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  40.4s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  40.7s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  37.6s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=  37.4s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  50.8s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.9s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  50.1s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  49.6s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.2s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  48.8s
# [Pipeline] ......... (step 1 of 2) Processing normalise, total=   2.9s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  24.7s

# %%
fittedgrid.best_estimator_
# Out:
# Pipeline(steps=[('normalise', StandardScaler()),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=15, min_samples_leaf=3,
#                                         random_state=12))],
#          verbose=True)

# %%
fittedgrid.best_score_
# Out:
# 0.8233324676600852

# %%
# retrieve the decision tree classifier from the pipeline
decision_tree_classifier = pipe[-1]

plt.figure(figsize=(20, 10))
plot_tree(decision_tree_classifier, max_depth=2, filled=True, feature_names=list(pipe[-2].get_feature_names_out()), class_names=["0","1"], rounded=True)
plt.show()

# %%
cross_val_score(pipe, X_train, y_train, cv=5)
# Out:
# [Pipeline] ......... (step 1 of 3) Processing normalise, total=   3.2s
# [Pipeline] ........ (step 2 of 3) Processing reduce_dim, total=  19.4s
# [Pipeline] ............. (step 3 of 3) Processing model, total=  10.3s
# [Pipeline] ......... (step 1 of 3) Processing normalise, total=   3.0s
# [Pipeline] ........ (step 2 of 3) Processing reduce_dim, total=  21.5s
# [Pipeline] ............. (step 3 of 3) Processing model, total=  10.2s
# [Pipeline] ......... (step 1 of 3) Processing normalise, total=   3.1s
# [Pipeline] ........ (step 2 of 3) Processing reduce_dim, total=  18.1s
# [Pipeline] ............. (step 3 of 3) Processing model, total=  10.2s
# [Pipeline] ......... (step 1 of 3) Processing normalise, total=   2.9s
# [Pipeline] ........ (step 2 of 3) Processing reduce_dim, total=  20.4s
# [Pipeline] ............. (step 3 of 3) Processing model, total=  10.3s
# [Pipeline] ......... (step 1 of 3) Processing normalise, total=   3.2s
# [Pipeline] ........ (step 2 of 3) Processing reduce_dim, total=  19.3s
# [Pipeline] ............. (step 3 of 3) Processing model, total=  10.2s
# array([0.81700135, 0.82329035, 0.8248626 , 0.82190762, 0.82385889])

# %%
# retrieve the decision tree classifier from the pipeline
decision_tree_classifier = pipe[-1]

plt.figure(figsize=(20, 10))
plot_tree(decision_tree_classifier, max_depth=2, filled=True, feature_names=list(pipe[-2].get_feature_names_out()), class_names=list(str(y_train.unique())), rounded=True)
plt.show()

# %%
y_pred_baseline_test= pipe.predict(X_test_transformed)

cm = confusion_matrix(y_test, y_pred_baseline_test)
# Out:
# /Users/edo/anaconda3/envs/es_capstone/lib/python3.8/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix on the test data - DT")
plt.show()
